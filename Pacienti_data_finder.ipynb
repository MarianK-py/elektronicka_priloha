# %%
import pandas as pd
import numpy as np
import yaml
import re

# %%
pacienti = pd.read_excel("Vysledky system.xlsx", sheet_name='Hárok1')
pacienti.set_index("Rodné číslo", inplace=True) 
pacienti["Olumiant"] = pacienti["Olumiant"].map({"ano":1, "áno":1, 0:0, 1:1})
pacienti["BMI"] = (pacienti["váha"]/((pacienti["výška"]/100)**2)).round(1)
#pacienti["dátum prijatia"] = pacienti["dátum prijatia"].dt.strftime('%d.%m.%Y')
pacienti["dátum prijatia"] = pd.to_datetime(pacienti["dátum prijatia"], format='%d.%m.%Y')
#pacienti["datum prepustenia"] = pacienti["datum prepustenia"].dt.strftime('%d.%m.%Y')
pacienti["datum prepustenia"] = pd.to_datetime(pacienti["datum prepustenia"], format='%d.%m.%Y')

# %% [markdown]
# Zoznamy a slovníky pre vyhľadávanie v texte

# %%
udaje = {"oxygenoterapia": ["Oxygenoterap", "oxygenoterap",
                            "HFNO", "high-flow", "high flow", "low-flow", "low flow",
                            "UPV", "umel.{1,5}pľúc.{1,5}venti.{8}", "CPAP",
                            "maska", "nosová kanyla"],
         "smrť": ["exitus", "exit.{11}", "lethalis", "leth.{5}"], 
         "JIS": ["JIS", "jedno.{2,6}inten.{5,9}staro.{10}"]}

vys_vah = [["výška.{0,3}[0-9]+.{0,2}cm"], ["váha.{0,3}[0-9]+.{0,2}kg", "hmotnosť.{0,3}[0-9]+.{0,2}kg"],
           ["[0-9]+.{0,2}cm.{0,2}/.{0,2}[0-9]+.{0,2}kg"], ["[0-9]+.{0,2}cm,.{0,2}[0-9]+.{0,2}kg"], ["[0-9]+.{0,2}cm .{0,2}[0-9]+.{0,2}kg"],
           ["[0-9]+.{0,2}kg.{0,2}/.{0,2}[0-9]+.{0,2}cm"], ["[0-9]+.{0,2}kg,.{0,2}[0-9]+.{0,2}cm"], ["[0-9]+.{0,2}kg .{0,2}[0-9]+.{0,2}cm"]]

vys_vah_sep = [["", ["výška"]], ["", ["váha"]], 
               ["/", ["výška", "váha"]], [",", ["výška", "váha"]], ["cm", ["výška", "váha"]], 
               ["/", ["váha", "výška"]], [",", ["váha", "výška"]], ["kg", ["váha", "výška"]]]

vys_basic = ["[0-9]+.{0,2}cm"]

vah_basic = ["[0-9]+.{0,2}kg"]

saturacia = ["spo2", "sato2", "sat.o2"]

saturacia_doplnky = ["", "pri prijati", "bez kyslík", "pri prijati bez kyslík"]

poz = ["poz"]

neg = ["neg"]

# %%
with open("informations.yml", "r", encoding='utf8') as f:
    inf = yaml.safe_load(f)

choroby = inf["choroby"]
vysledky = inf["vysledky"]
lieky = inf["lieky"]
protilatky = inf["protilatky"]
vyber = inf["vyberove"]

# %% [markdown]
# Funkcia ktorá v z dataframu spravý text a zavolá vyhľadávacie funkcie

# %%
def text_finder(pacient):
    hlavny_text = ""
    imuno_text = ""
    data = dict()
    data_temp = dict()
    problemy = []
    problemy_temp = []
    nenajdene = dict()
    
    start_imuno = False
    for index, value in pacient.iloc[:,0].items():
        if(value == "Imunologické vyš.:"):
            start_imuno = True
        if(type(value) !=  float):
            if start_imuno:
                imuno_text += str(value)+"\n"
            else:
                hlavny_text += str(value)+"\n"
    
    #Osobne udaje:
    if vyber["hlavicka"]:
        data_temp, problemy_temp = osobne_udaje(pacient)
        data.update(data_temp)
        problemy += problemy_temp
    
    if ("chýba správa" in hlavny_text):
        print(pacient.iloc[:,0][0])
        print("Chýba správa")
        print()
        return data, ["chýba správa"], []
    
    #Zakl. udaje:
    data_temp, problemy_temp = find_stav_pac(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp
    
    #Protilátky pri prijatí:
    for p in protilatky.values():
        data_temp, problemy_temp = find_protilatky(hlavny_text, p)
        data.update(data_temp)
        problemy += problemy_temp
    
    #Vyska/vaha:
    data_temp, problemy_temp = find_vys_vah(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp
    if (len(problemy_temp) == 0):
        BMI = round(data["váha"]/((data["výška"]/100)**2), 1)
        if (BMI > 60 or BMI < 10):
            problemy.append("BMI")
    
    #Saturacia:
    data_temp, problemy_temp = find_saturacia(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp 
        
    #Lieky:
    data_temp = find_lieky(hlavny_text)
    data.update(data_temp)
        
    #Vylsedky:  
    if (imuno_text != ""):
        data_temp, problemy_temp, nenajdene = find_vysledky(imuno_text, vysledky)
        if (len(nenajdene) != 0):
            data.update(data_temp)
            problemy += problemy_temp
            data_temp, problemy_temp, nenajdene = find_vysledky(hlavny_text, nenajdene)
    else:
        data_temp, problemy_temp, nenajdene = find_vysledky(hlavny_text, vysledky)
    data.update(data_temp)
    problemy += problemy_temp 
            
    #Choroby: 
    data_temp, problemy_temp = find_choroby(hlavny_text)
    data.update(data_temp)
    problemy += problemy_temp 
    
    print(pacient.iloc[:,0][0])
    print("Problematické údaje:",problemy)
    print("Nenajdene vysl.:",list(nenajdene.keys()))
    print()
    
    return data, problemy, list(nenajdene.keys())

# %% [markdown]
# Funkcia hľadajúce udaje ako meno, RČ a dobu hospitalizácie

# %%
def osobne_udaje(pacient):
    data = dict()
    problemy = []

    data["Meno"] = pacient[pacient.columns[0]][0].strip()
    data["Rodné číslo"] = pacient[pacient.columns[1]][0].strip()
    found_pri = False
    try:
        data["dátum prijatia"] = pd.to_datetime(pacient[pacient.columns[2]][0], format="%d.%m.%Y")
        found_pri = True
    except:
        problemy.append("dátum prijatia")

    found_pre = False
    if (type(pacient[pacient.columns[3]][0]) is str):
        if ("preklad" in pacient[pacient.columns[3]][0]):
            try:
                data["datum prepustenia"] = pd.to_datetime(pacient[pacient.columns[4]][0], format="%d.%m.%Y")
                found_pre = True
            except:
                problemy.append("dátum prepustenia (preklad)")
        else:
            try:
                data["datum prepustenia"] = pd.to_datetime(pacient[pacient.columns[3]][0], format="%d.%m.%Y")
                found_pre = True
            except:
                problemy.append("dátum prepustenia (bez prekladu)")
    else:
        try:
            data["datum prepustenia"] = pd.to_datetime(pacient[pacient.columns[3]][0], format="%d.%m.%Y")
            found_pre = True
        except:
            problemy.append("dátum prepustenia (bez prekladu)")
    if vyber["doba_hospitalizacie"]:
        if found_pri and found_pre:
            data["dlžka hosp."] = (data["datum prepustenia"] - data["dátum prijatia"]).days
            if (data["dlžka hosp."] < 0 or data["dlžka hosp."] > 100):
                    problemy.append("dlzka hospitalizacie")

    if found_pri:
        rok_nar = int(data["Rodné číslo"][0:2])
        if (rok_nar < 22):
            if len(data["Rodné číslo"]) == 11:
                rok_nar += 100
        mes_nar = int(data["Rodné číslo"][2:4])
        if (mes_nar > 50):
            mes_nar -= 50
        den_nar = int(data["Rodné číslo"][4:6])

        vek = 0

        if (data["dátum prijatia"].month < mes_nar):
            vek = (data["dátum prijatia"].year - 1901) - rok_nar
        elif (data["dátum prijatia"].month > mes_nar):
            vek = (data["dátum prijatia"].year - 1900) - rok_nar
        else:
            if (data["dátum prijatia"].day < den_nar):
                vek = (data["dátum prijatia"].year - 1901) - rok_nar
            elif (data["dátum prijatia"].day >= den_nar):
                vek = (data["dátum prijatia"].year - 1900) - rok_nar

        if vyber["vek"]:
            if vek >= 0 and vek < 120:
                data["vek"] = vek
            else:
                problemy.append("vek")

        data["dátum prijatia"] = data["dátum prijatia"].strftime('%d.%m.%Y')

    if found_pre:
        data["datum prepustenia"] = data["datum prepustenia"].strftime('%d.%m.%Y')
    
    return data, problemy

# %% [markdown]
# Hľadanie udajov o stave pacienta ako oxygenoterapia/JIS/smrť

# %%
def find_stav_pac(text):
    data = dict()
    problemy = []
    for i, udaj in udaje.items():
        out = []
        for j in udaj:
            out += re.findall(j,text)
        if vyber[i]:
            if (i == "oxygenoterapia"):

                if (len(out) == 0):
                    data[i] = "bez oxygenoterapie"
                else:
                    if (("HFNO" in out) or ("high-flow" in out) or ("high flow" in out)):
                        if ("UPV" in out):
                            data[i] = "HFNO/UPV"
                        else:
                            data[i] = "HFNO"
                    elif ("UPV" in out):
                        data[i] = "UPV"
                    elif (("low-flow" in out) or ("low flow" in out)):
                        data[i] = "low-flow"
                    else:
                        data[i] = "low-flow (neupresnené)"
                        chyba = re.findall("bez oxygenoterap",text)
                        if len(chyba) > 0:
                            data[i] = ""
                            problemy.append("oxygenoterapia")
            else:
                if (len(out) == 0):
                    data[i] = 0
                else:
                    data[i] = 1
        
    return data, problemy

# %% [markdown]
# Funkcia hľadajúca informácie o protilátkach

# %%
def find_protilatky(text, ochorenie):
    out = []
    problemy = []
    data = dict()
    text = text.lower()
    protilatky = ochorenie["nazvy_protilatok"]
    stlpce = ochorenie["nazvy_stlpcov"]
    proti_dolezite = poz+neg+protilatky

    if len(protilatky) == 0:
        for n in ochorenie["nazvy_ochorenia"]:
            for vysl in (poz+neg):
                out += re.findall(n+".{0,40}"+vysl,text)

        if (out != []):
            for test in out:
                rozdel_test = re.split(",| |/|:|-|\(|\)|–",test)
                #print(rozdel_test)
                for i in rozdel_test.copy():
                    remove = True
                    for p in proti_dolezite:
                        if p in i:
                            remove = False
                    if remove or i == "":
                        rozdel_test.remove(i)

                for i in rozdel_test:
                    if neg[0] in i:
                        data[stlpce[0]] = 0
                    if poz[0] in i:
                        data[stlpce[0]] = data.get(stlpce[0], 1)*1

    elif len(protilatky) == 1:
        for n in ochorenie["nazvy_ochorenia"]:
            for vysl in (poz+neg):
                out += re.findall(n+".{0,40}"+protilatky[0]+".{0,10}"+vysl,text)

        if (out != []):
            for test in out:
                rozdel_test = re.split(",| |/|:|-|\(|\)|–",test)
                #print(rozdel_test)
                for i in rozdel_test.copy():
                    remove = True
                    for p in proti_dolezite:
                        if p in i:
                            remove = False
                    if remove or i == "":
                        rozdel_test.remove(i)

                for i in rozdel_test:
                    if neg[0] in i:
                        data[stlpce[0]] = 0
                    if poz[0] in i:
                        data[stlpce[0]] = data.get(stlpce[0], 1)*1

        for i in stlpce:
            if i not in data:
                problemy.append(i)

    else:
        for n in ochorenie["nazvy_ochorenia"]:
            for vysl in (poz+neg):
                out += re.findall(n+".{0,40}"+protilatky[0]+".{0,30}"+protilatky[1]+".{0,10}"+vysl,text)
                out += re.findall(n+".{0,40}"+protilatky[1]+".{0,30}"+protilatky[0]+".{0,10}"+vysl,text)

            out += re.findall(n+".{0,40}"+protilatky[1]+".{0,30}"+protilatky[0]+".{0,20}",text)
            out += re.findall(n+".{0,40}"+protilatky[0]+".{0,30}"+protilatky[1]+".{0,20}",text)

        if (out != []):
            for test in out:
                rozdel_test = re.split(",| |/|:|-|\(|\)|–",test)
                #print(rozdel_test)
                for i in rozdel_test.copy():
                    remove = True
                    for p in proti_dolezite:
                        if p in i:
                            remove = False
                    if remove or i == "":
                        rozdel_test.remove(i)


                #print(rozdel_test)

                IgM, IgG = pozicie_testov(rozdel_test, protilatky)

                counter = 0
                while (IgM != -1 and IgG != -1 and counter < 5):
                    vysl = vysledky_testov(IgM, IgG, rozdel_test)
                    if (vysl[0] != -1):
                        data[stlpce[1]] = data.get(stlpce[1], 1) * vysl[0]
                    if (vysl[1] != -1):
                        data[stlpce[0]] = data.get(stlpce[0], 1) * vysl[0]
                    rozdel_test = rozdel_test[(max(IgM, IgG))+1:]
                    IgM, IgG = pozicie_testov(rozdel_test, protilatky)
                    counter += 1
        for i in stlpce:
            if i not in data:
                problemy.append(i)

        #print(data)
    return data, problemy

# %% [markdown]
# Zisťovanie pozitivity/negativity

# %%
def poz_alebo_neg(vysl):
    pozit = []
    negat = []
    
    if vysl.isdigit():
        return 1
    
    for p in poz:
        pozit += re.findall(p, vysl)
    for n in neg:
        negat += re.findall(n, vysl)

    if (pozit == [] and negat == []) or (pozit != [] and negat != []):
        return -1
    elif pozit != []:
        return 1
    else:
        return 0

# %%
def pozicie_testov(rozdel_test, proti):
    IgM = -1
    if (proti[1] in rozdel_test):
        IgM = rozdel_test.index(proti[1])
    else:
        for j, cast in enumerate(rozdel_test):
            if proti[1] in cast:
                IgM = j
                
    IgG = -1
    if (proti[0] in rozdel_test):
        IgG = rozdel_test.index(proti[0])
    else:
        for j, cast in enumerate(rozdel_test):
            if proti[0] in cast:
                IgG = j
                
    return [IgM, IgG]

# %% [markdown]
# Hľadanie výseldkov jendého protilátkového testu

# %%
def vysledky_testov(IgM, IgG, rozdel_test):
    pocet_casti = len(rozdel_test)
    vysl = [-1, -1]
    swap = False
    if (IgM > IgG):
        swap = True
        IgM, IgG = IgG, IgM
        
    if (IgM > 0):
        pozitM1 = poz_alebo_neg(rozdel_test[IgM-1])
    else:
        pozitM1 = -1
    if (IgM+1 < pocet_casti):
        pozitM2 = poz_alebo_neg(rozdel_test[IgM+1])
    else:
        pozitM2 = -1
                    
    if (IgG > 0):
        pozitG1 = poz_alebo_neg(rozdel_test[IgG-1])
    else:
        pozitG1 = -1
    if (IgG+1 < pocet_casti):
        pozitG2 = poz_alebo_neg(rozdel_test[IgG+1])
    else:
        pozitG2 = -1


    if (pozitM1 != -1):
        vysl[0] = pozitM1
    elif (pozitM2 != -1):
        vysl[0] = pozitM2
    elif (IgM+1 == IgG):
        if (pozitG2 != -1):
            vysl[0] = pozitG2

    if (pozitG2 != -1):
        vysl[1] = pozitG2
    elif (pozitG1 != -1):
        vysl[1] = pozitG1
    elif (IgM+1 == IgG):
        if (pozitM1 != -1):
            vysl[1] = pozitM1

    if (pozitM1 == -1 and pozitG2 == -1 and IgG != -1 and IgM != -1):
        vysl = [-1, -1]

    if (pozitM1 != -1 and pozitM2 != -1 and IgG == -1 ):
        vysl[0] = -1

    if (pozitG1 != -1 and pozitG2 != -1 and IgM == -1):
        vysl[1] = -1

    if swap:
        vysl.reverse()
        
    return vysl

# %% [markdown]
# Hľadanie výšky/váhy

# %%
def find_vys_vah(text):
    data = dict()
    problemy = []
    for i, hod in enumerate(vys_vah):
        out = []
        for j in hod:
            out += re.findall(j,text)
        if (out != []):
            for k in out:
                if vys_vah_sep[i][0] != "":
                    separated = k.split(vys_vah_sep[i][0])
                else:
                    separated = [k]
                for l, sep in enumerate(separated):
                    #print(vys_vah_sep[i][1][l],re.findall("[0-9]+",sep)[0])
                    data[vys_vah_sep[i][1][l]] = int(re.findall("[0-9]+",sep)[0])
                    if (vys_vah_sep[i][1][l] == "výška" and
                            (data["výška"] > 250 or data["výška"] < 20)):
                        problemy.append("výška")
                    elif (vys_vah_sep[i][1][l] == "váha" and
                            (data["váha"] > 300 or data["váha"] < 10)):
                        problemy.append("váha")
    if ("výška" not in data):
        problemy.append("výška")
    if ("váha" not in data):
        problemy.append("váha")
        
    return data, problemy

# %% [markdown]
# Hľadanie saturácie

# %%
def find_saturacia(text):
    data = dict()
    problemy = []
    text = text.lower()
    
    hodnoty_text = []
    hodnoty_cisla = []
    
    for sat in saturacia:
        for dop in saturacia_doplnky:
            if dop == "":
                hodnoty_text += re.findall(sat+".{1,3}[0-9]+",text)
            else:
                hodnoty_text += re.findall(sat+".{1,3}"+dop+".{1,3}[0-9]+",text)
        
    for hod in hodnoty_text:
        hod_cislo = int(re.findall("[0-9]+", hod)[-1])
        if (hod_cislo != 0 and hod_cislo <= 100):
            hodnoty_cisla.append(hod_cislo)
    
    if (len(hodnoty_cisla) != 0):
        data["SpO2 pri prijati bez kyslika"] = hodnoty_cisla[0]
    else:
        problemy.append("SpO2 pri prijati bez kyslika")
        
    return data, problemy

# %% [markdown]
# Hľadanie liekov

# %%
def find_lieky(text):
    text = text.lower()
    data = dict()
    for i, liekMena in lieky.items():
        out = []
        for liek in liekMena:
            out += re.findall(liek,text)
        if (len(out) == 0):
            #print(i,"= 0")
            data[i] = 0
        else:
            #print(i,"= 1")
            data[i] = 1
    return data

# %% [markdown]
# Hľadanie vysledkov krvných testov

# %%
def find_vysledky(text, vysledky_input):
    data = dict()
    problemy = []
    nenajdene = dict()
    for i, vysl in vysledky_input.items():
        hodnoty_text = []
        hodnoty_cisla = []
        
        for j in vysl:
            hodnoty_text += re.findall(j+".{1,3}[0-9,]+",text)
            
        for hod in hodnoty_text:
            hod_cislo = re.findall("[0-9,]+", hod)[-1].replace(",",".")
            if (hod_cislo != "."):
                if (hod_cislo[-1] == "."):
                    if (hod_cislo[0:-1].count(".") > 1):
                        problemy.append(i)
                    else:
                        hodnoty_cisla.append(float(hod_cislo[0:-1]))
                else:
                    if (hod_cislo.count(".") > 1):
                        problemy.append(i)
                    else:
                        hodnoty_cisla.append(float(hod_cislo))
                        
        if (len(hodnoty_cisla) == 0):
            nenajdene[i] = vysl
        elif (len(hodnoty_cisla) == 1):
            data[i] = hodnoty_cisla[0]
            #print(i,"=",hodnoty_cisla[0])
        else:
            prva_hod = hodnoty_cisla[0]
            for hod in hodnoty_cisla:
                if (prva_hod != hod):
                    if (i not in problemy):
                            problemy.append(i)
                else:
                    prva_hod = hod          
            data[i] = prva_hod
        
    return data, problemy, nenajdene

# %% [markdown]
# Hľadanie chorôb u pacienta

# %%
def find_choroby(text):
    data = dict()
    problemy = []
    for i, chor in choroby.items():
        out = []
        for j in chor:
            out += re.findall(j,text)
        if (len(out) == 0):
            #print(i,"= 0")
            data[i] = 0
        if (out != []):
            if (i == "CDI pri hosp"):
                vysl = kolitida_kontrola(text)
                if (vysl != -1):
                    data[i] = vysl
                else:
                    problemy.append("CDI pri hosp")
                #print(i, "problem")
            else:
                #print(i,"= 1",out)
                data[i] = 1
    return data, problemy

# %% [markdown]
# Špeciálna kontrola pri kolitide

# %%
def kolitida_kontrola(text):
    pozit = []
    negat = []
    for chor in choroby["CDI pri hosp"]:
        for p in poz:
            pozit += re.findall(chor+".{0,20}"+p, text)
        for n in neg:
            negat += re.findall(chor+".{0,20}"+n, text)
    
    if ((pozit == [] and negat == []) or (pozit != [] and negat != [])):
        return -1
    elif (pozit != []):
        return 1
    else:
        return 0

# %% [markdown]
# Pridávanie dových výsledkov do hlavného dataframu (vypisovanie problémov) (vstup čísla harkov)

# %%
def pridavanie_udajov(citany_subor, zapisovaci_subor,a, b):
    pacienti = pd.read_excel(zapisovaci_subor, sheet_name='Hárok1')
    pacienti.set_index("Rodné číslo", inplace=True) 
    if ("Deaxmetazon" in pacienti.columns):
        pacienti.rename(columns = {'Deaxmetazon':'Dexametazon'}, inplace = True)
    
    data = dict()
    problemy = []
    nenajdene = []
    with open("problemy "+citany_subor+".txt", "w", encoding='utf8') as problemy_dokument: 
        for p in range(a, b+1):
            print(f"Pacient z hárku {p}")
            try:
                pacient = pd.read_excel(citany_subor, sheet_name=f"Hárok{p}")
                if (len(pacient) == 0 or len(pacient) == 1):
                    print(f"Problém s hárkom {p}")
                    print()
                    continue
            except:
                print(f"Problém s hárkom {p}")
                print()
                continue
            data, problemy, nenajdene = text_finder(pacient)
            problemy_dokument.write(f"Pacient z hárku {p}:\n")
            problemy_dokument.write(f"Meno pacienta: {pacient.iloc[:,0][0]}\n")
            if ("chýba správa" in problemy):
                problemy_dokument.write(f"Chýba správa\n")
            else:
                problemy_dokument.write(f"Problemove udaje: {problemy}\n")
                problemy_dokument.write(f"Nenajdene vysledky: {nenajdene}\n")
            problemy_dokument.write("\n")
            if data != None:
                RC = data.pop("Rodné číslo")
                if (RC in pacienti.index):
                    print("Problém s menom:",data["Meno"],pacienti.loc[RC,"Meno"])
                    if data["Meno"] != pacienti.loc[RC,"Meno"]:
                        print("Problém s menom:",data["Meno"],pacienti.loc[RC,"Meno"])
                    for i, hod in data.items():
                        pacienti.loc[RC,i] = hod
                else:
                    pacienti.loc[RC] = data
    
    pacienti.reset_index(inplace=True)
    
    cols = list(pacienti.columns)
    a, b = cols.index('Meno'), cols.index('Rodné číslo')
    cols[b], cols[a] = cols[a], cols[b]
    pacienti = pacienti[cols]
    
    
    pacienti["Olumiant"] = pacienti["Olumiant"].map({"ano":1, "áno":1, 0:0, 1:1})
    pacienti["BMI"] = (pacienti["váha"]/((pacienti["výška"]/100)**2)).round(1)
    #pacienti["dátum prijatia"] = pacienti["dátum prijatia"].dt.strftime('%d.%m.%Y')
    #pacienti["datum prepustenia"] = pacienti["datum prepustenia"].dt.strftime('%d.%m.%Y')
    if "Unnamed: 26" in pacienti:
        del pacienti["Unnamed: 26"]
    if "dni" in pacienti:
        del pacienti["dni"]
    for i in re.findall("Dexametazon\.[0-9]+", str(pacienti.columns)):
        del pacienti[i]
    
    pacienti.to_excel(zapisovaci_subor, sheet_name="Hárok1",index = False)

# %%
from time import perf_counter

# %%
#pridavanie_udajov("Antivirotika KIGM COVID-19.xlsx", "Antivirotika KIGM COVID-19 doplnene.xlsx",2, 384)
#pridavanie_udajov("Antivirotika 2 KIGM COVID-19.xlsx", "Antivirotika KIGM COVID-19 doplnene.xlsx",1, 107)
#pridavanie_udajov("Antivirotika 2 KIGM COVID-19.xlsx", "Antivirotika KIGM COVID-19 doplnene special_2.xlsx",1, 107)
t = 0
for i in range(10):
    s = perf_counter()
    #pridavanie_udajov("Pacienti.xlsx", "Vysledky system.xlsx", 1, 101)
    e = perf_counter()
    print(e-s)
    t += e-s
print(t/10)
# Out:
# 5.00003807246685e-07
# 3.00002284348011e-07
# 1.00000761449337e-07
# 2.00001522898674e-07
# 2.00001522898674e-07
# 1.00000761449337e-07
# 9.997165761888027e-08
# 1.00000761449337e-07
# 2.00001522898674e-07
# 9.997165761888027e-08
# 1.8999562598764896e-07

# %%
pridavanie_udajov("Pacienti.xlsx", "Vysledky system.xlsx", 1, 101)
# Out:
# Pacient z hárku 1
# Poláček Miroslav
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Poláček Miroslav Poláček Miroslav
# Pacient z hárku 2
# Poláčková Anna
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'D vit', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Poláčková Anna Poláčková Anna
# Pacient z hárku 3
# Polgár Zoltán
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Polgár Zoltán Polgár Zoltán
# Pacient z hárku 4
# Poliačiková Anna
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Poliačiková Anna Poliačiková Anna
# Pacient z hárku 5
# Popová Anna
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Popová Anna Popová Anna
# Pacient z hárku 6
# Pošík Peter, Mgr.
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Pošík Peter, Mgr. Pošík Peter, Mgr.
# Pacient z hárku 7
# Pruša Juraj, Mgr.
# Problematické údaje: []
# Nenajdene vysl.: []
#
# Problém s menom: Pruša Juraj, Mgr. Pruša Juraj, Mgr.
# Pacient z hárku 8
# Průžek Jiří
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Průžek Jiří Průžek Jiří
# Pacient z hárku 9
# Pukšová Anna
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Pukšová Anna Pukšová Anna
# Pacient z hárku 10
# Pulat Sahin
# Problematické údaje: ['CDI pri hosp']
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Pulat Sahin Pulat Sahin
# Pacient z hárku 11
# Pulc Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Pulc Jozef Pulc Jozef
# Pacient z hárku 12
# Pytel Martin
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Pytel Martin Pytel Martin
# Pacient z hárku 13
# Rakovská Monika
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Rakovská Monika Rakovská Monika
# Pacient z hárku 14
# Reháková Zuzana
# Problematické údaje: ['PCT']
# Nenajdene vysl.: ['TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Reháková Zuzana Reháková Zuzana
# Pacient z hárku 15
# Repka Ivan
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Repka Ivan Repka Ivan
# Pacient z hárku 16
# Rexová Magdaléna
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Rexová Magdaléna Rexová Magdaléna
# Pacient z hárku 17
# Rezek Michal
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Problém s menom: Rezek Michal Rezek Michal
# Pacient z hárku 18
# Rigóová Oľga
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Problém s menom: Rigóová Oľga Rigóová Oľga
# Pacient z hárku 19
# Roeswenda Raden Tiny
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Problém s menom: Roeswenda Raden Tiny Roeswenda Raden Tiny
# Pacient z hárku 20
# Rovniansky Vladimír
# Problematické údaje: []
# Nenajdene vysl.: []
#
# Problém s menom: Rovniansky Vladimír Rovniansky Vladimír
# Pacient z hárku 21
# Rozbora Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Rozbora Jozef Rozbora Jozef
# Pacient z hárku 22
# Rozborová Mária
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Rozborová Mária Rozborová Mária
# Pacient z hárku 23
# Sakmár Anton
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Sakmár Anton Sakmár Anton
# Pacient z hárku 24
# Samuhel Marian
# Problematické údaje: ['oxygenoterapia']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Samuhel Marian Samuhel Marian
# Pacient z hárku 25
# Schwartz Peter
# Problematické údaje: ['CDI pri hosp']
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Schwartz Peter Schwartz Peter
# Pacient z hárku 26
# Shapovalov Oleg
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Shapovalov Oleg Shapovalov Oleg
# Pacient z hárku 27
# Shonde Gbenga Abayom
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'D vit', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Shonde Gbenga Abayom Shonde Gbenga Abayom
# Pacient z hárku 28
# Shramko Andrii
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Shramko Andrii Shramko Andrii
# Pacient z hárku 29
# Singer Tomáš, Mgr.
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Singer Tomáš, Mgr. Singer Tomáš, Mgr.
# Pacient z hárku 30
# Slaboň Pavol
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Slaboň Pavol Slaboň Pavol
# Pacient z hárku 31
# Slaný Juraj, Ing.
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Slaný Juraj, Ing. Slaný Juraj, Ing.
# Pacient z hárku 32
# Slivková Jozefína
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Slivková Jozefína Slivková Jozefína
# Pacient z hárku 33
# Soboličová Margita
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Soboličová Margita Soboličová Margita
# Pacient z hárku 34
# Soldán Jozef
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'váha']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Problém s menom: Soldán Jozef Soldán Jozef
# Pacient z hárku 35
# Stachová Anna
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Stachová Anna Stachová Anna
# Pacient z hárku 36
# Stránska Melánia
# Problematické údaje: ['PCT']
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Stránska Melánia Stránska Melánia
# Pacient z hárku 37
# Strnadová Mária
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Problém s menom: Strnadová Mária Strnadová Mária
# Pacient z hárku 38
# Strnátková Mária
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Strnátková Mária Strnátková Mária
# Pacient z hárku 39
# Stručka Ľubomír
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Stručka Ľubomír Stručka Ľubomír
# Pacient z hárku 40
# Strýček Pavol
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Strýček Pavol Strýček Pavol
# Pacient z hárku 41
# Suchánková Martina
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Suchánková Martina Suchánková Martina
# Pacient z hárku 42
# Szalay Adrián, Mgr.
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Szalay Adrián, Mgr. Szalay Adrián, Mgr.
# Pacient z hárku 43
# Szalay Juraj
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Szalay Juraj Szalay Juraj
# Pacient z hárku 44
# Szluková Ľubica
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha', 'CDI pri hosp']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Szluková Ľubica Szluková Ľubica
# Pacient z hárku 45
# Szöcsová Daniela
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Szöcsová Daniela Szöcsová Daniela
# Pacient z hárku 46
# Szulányi Ľudovít
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Szulányi Ľudovít Szulányi Ľudovít
# Pacient z hárku 47
# Šaradin Róbert
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Šaradin Róbert Šaradin Róbert
# Pacient z hárku 48
# Šarközy Ondrej
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Šarközy Ondrej Šarközy Ondrej
# Pacient z hárku 49
# Šarlinová Jana
# Problematické údaje: []
# Nenajdene vysl.: ['IL-6', 'PCT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Šarlinová Jana Šarlinová Jana
# Pacient z hárku 50
# Šatura Juraj
# Problematické údaje: []
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Problém s menom: Šatura Juraj Šatura Juraj
# Pacient z hárku 51
# Ščasný Alojz
# Problematické údaje: ['výška', 'váha', 'IL-6']
# Nenajdene vysl.: ['D vit', 'GMT', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Ščasný Alojz Ščasný Alojz
# Pacient z hárku 52
# Ščepka Milan
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Ščepka Milan Ščepka Milan
# Pacient z hárku 53
# Ščepka Pavol
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Ščepka Pavol Ščepka Pavol
# Pacient z hárku 54
# Šípošová Mária
# Problematické údaje: []
# Nenajdene vysl.: ['D vit']
#
# Problém s menom: Šípošová Mária Šípošová Mária
# Pacient z hárku 55
# Škoda Štefan
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Škoda Štefan Škoda Štefan
# Pacient z hárku 56
# Štefek Marián
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Štefek Marián Štefek Marián
# Pacient z hárku 57
# Šteffek Ľuboš
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Šteffek Ľuboš Šteffek Ľuboš
# Pacient z hárku 58
# Štulrajter Ľubomír
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Štulrajter Ľubomír Štulrajter Ľubomír
# Pacient z hárku 59
# Problém s hárkom 59
#
# Pacient z hárku 60
# Šúry Peter
# Problematické údaje: []
# Nenajdene vysl.: []
#
# Problém s menom: Šúry Peter Šúry Peter
# Pacient z hárku 61
# Tarariiev Vilalii
# Problematické údaje: ['D vit']
# Nenajdene vysl.: ['PCT', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Tarariiev Vilalii Tarariiev Vilalii
# Pacient z hárku 62
# Tavaliová Anastázia
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['D vit', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Tavaliová Anastázia Tavaliová Anastázia
# Pacient z hárku 63
# Tencerová Anna
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Tencerová Anna Tencerová Anna
# Pacient z hárku 64
# Tibenský Vladimír
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Tibenský Vladimír Tibenský Vladimír
# Pacient z hárku 65
# Tománek Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Tománek Jozef Tománek Jozef
# Pacient z hárku 66
# Tomeček Drahoslav
# Problematické údaje: []
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Tomeček Drahoslav Tomeček Drahoslav
# Pacient z hárku 67
# Tóth Miloš
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Tóth Miloš Tóth Miloš
# Pacient z hárku 68
# Trebuľová Priska
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Trebuľová Priska Trebuľová Priska
# Pacient z hárku 69
# Trubar Jaroslav
# Problematické údaje: ['D vit']
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Trubar Jaroslav Trubar Jaroslav
# Pacient z hárku 70
# Truben Albert
# Problematické údaje: ['výška']
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Truben Albert Truben Albert
# Pacient z hárku 71
# Uhlík Milan
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Uhlík Milan Uhlík Milan
# Pacient z hárku 72
# Ujlaky Peter
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Ujlaky Peter Ujlaky Peter
# Pacient z hárku 73
# Ulbrich Tomáš
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Ulbrich Tomáš Ulbrich Tomáš
# Pacient z hárku 74
# Vajas Tomáš
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT']
#
# Problém s menom: Vajas Tomáš Vajas Tomáš
# Pacient z hárku 75
# Valachovič Pavol
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['IL-6', 'PCT', 'feritín', 'TnT']
#
# Problém s menom: Valachovič Pavol Valachovič Pavol
# Pacient z hárku 76
# Valdner Ivan, Ing.
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín']
#
# Problém s menom: Valdner Ivan, Ing. Valdner Ivan, Ing.
# Pacient z hárku 77
# Varadínová Milena
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Varadínová Milena Varadínová Milena
# Pacient z hárku 78
# Varga Juraj, Mgr.
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'PCT', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Varga Juraj, Mgr. Varga Juraj, Mgr.
# Pacient z hárku 79
# Varga Pavol, Ing.
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Varga Pavol, Ing. Varga Pavol, Ing.
# Pacient z hárku 80
# Váry Mikuláš, Ing.
# Problematické údaje: ['SpO2 pri prijati bez kyslika']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Váry Mikuláš, Ing. Váry Mikuláš, Ing.
# Pacient z hárku 81
# Vážny Rastislav
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Vážny Rastislav Vážny Rastislav
# Pacient z hárku 82
# Velschmidt Oľga
# Problematické údaje: []
# Nenajdene vysl.: []
#
# Problém s menom: Velschmidt Oľga Velschmidt Oľga
# Pacient z hárku 83
# Veselý Dušan
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['CD4 abs', 'CD8 abs']
#
# Problém s menom: Veselý Dušan Veselý Dušan
# Pacient z hárku 84
# Veverková Melinda
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Veverková Melinda Veverková Melinda
# Pacient z hárku 85
# Vicena Adrián, JUDr.
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Vicena Adrián, JUDr. Vicena Adrián, JUDr.
# Pacient z hárku 86
# Vidovič Stanislav
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['PCT', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Vidovič Stanislav Vidovič Stanislav
# Pacient z hárku 87
# Világi Arpád
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Világi Arpád Világi Arpád
# Pacient z hárku 88
# Viola František
# Problematické údaje: []
# Nenajdene vysl.: ['D vit', 'feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Viola František Viola František
# Pacient z hárku 89
# Vizváry Miroslav
# Problematické údaje: []
# Nenajdene vysl.: ['PCT', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Vizváry Miroslav Vizváry Miroslav
# Pacient z hárku 90
# Vlado Michal
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Vlado Michal Vlado Michal
# Pacient z hárku 91
# Vlk Jozef
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Vlk Jozef Vlk Jozef
# Pacient z hárku 92
# Voberová Andrea
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Voberová Andrea Voberová Andrea
# Pacient z hárku 93
# Vonk Jan Nanno Wiert
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Vonk Jan Nanno Wiert Vonk Jan Nanno Wiert
# Pacient z hárku 94
# Vörös Karol
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí', 'výška', 'váha', 'CDI pri hosp']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Vörös Karol Vörös Karol
# Pacient z hárku 95
# Voznická Mária
# Problematické údaje: []
# Nenajdene vysl.: ['IL-6', 'feritín']
#
# Problém s menom: Voznická Mária Voznická Mária
# Pacient z hárku 96
# Wágnerová Miroslava
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Wágnerová Miroslava Wágnerová Miroslava
# Pacient z hárku 97
# Wiedermannová Anna
# Problematické údaje: []
# Nenajdene vysl.: ['feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Wiedermannová Anna Wiedermannová Anna
# Pacient z hárku 98
# Zábojníková Katarína
# Problematické údaje: ['IgG pri prijatí', 'IgM pri prijatí']
# Nenajdene vysl.: ['IL-6', 'D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Zábojníková Katarína Zábojníková Katarína
# Pacient z hárku 99
# Zajac Anton
# Problematické údaje: []
# Nenajdene vysl.: ['feritín']
#
# Problém s menom: Zajac Anton Zajac Anton
# Pacient z hárku 100
# Zavřelová Viera
# Problematické údaje: ['výška', 'váha']
# Nenajdene vysl.: ['feritín', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Zavřelová Viera Zavřelová Viera
# Pacient z hárku 101
# Zednikovičová Ľubica
# Problematické údaje: ['CDI pri hosp']
# Nenajdene vysl.: ['D vit', 'feritín', 'TnT', 'CD4 abs', 'CD8 abs']
#
# Problém s menom: Zednikovičová Ľubica Zednikovičová Ľubica

# %%
pacient = pd.read_excel("Pacienti.xlsx", sheet_name=f"Hárok{2}")

hlavny_text = ""
imuno_text = ""
data = dict()
data_temp = dict()
problemy = []
problemy_temp = []
nenajdene = dict()

start_imuno = False
for index, value in pacient.iloc[:,0].items():
    if(value == "Imunologické vyš.:"):
        start_imuno = True
    if(type(value) !=  float):
        if start_imuno:
            imuno_text += str(value)+"\n"
        else:
            hlavny_text += str(value)+"\n"

# %%
find_choroby(hlavny_text)

# %%
re.findall('hypertenz',hlavny_text)
